# %% [markdown]
# # Assignment 1
# # Andreas Dimas Christanto
# # PYTN-KS-017

# %%
#Memasukkan library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from PIL import Image
import folium

# %%
# !conda install -c anaconda xlrd --yes

# %%
df_can = pd.read_csv('london_crime_by_lsoa.csv')
print('Data read into a pandas dataframe!')
# Out:
# Data read into a pandas dataframe!

# %%
df_can.head(100)
# Out:
#     lsoa_code     borough               major_category  \
# 0   E01001116     Croydon                     Burglary
# 1   E01001646   Greenwich  Violence Against the Person
# 2   E01000677     Bromley  Violence Against the Person
# 3   E01003774   Redbridge                     Burglary
# 4   E01004563  Wandsworth                      Robbery
# ..        ...         ...                          ...
# 95  E01002093    Haringey  Violence Against the Person
# 96  E01002374    Havering                      Robbery
# 97  E01004142      Sutton                     Burglary
# 98  E01000401      Bexley  Violence Against the Person
# 99  E01000223      Barnet  Violence Against the Person
#
#                  minor_category  value  year  month
# 0   Burglary in Other Buildings      0  2016     11
# 1                Other violence      0  2016     11
# 2                Other violence      0  2015      5
# 3   Burglary in Other Buildings      0  2016      3
# ...

# %%
df_can.shape
# Out:
# (13490604, 7)

# %%
df_can.columns
# Out:
# Index(['lsoa_code', 'borough', 'major_category', 'minor_category', 'value',
#        'year', 'month'],
#       dtype='object')

# %% [markdown]
# - boroguh = wilayah

# %%
# lets rename
df_can.rename(columns={'lsoa_code':'Police Code','borough':'Region','major_category':'Crime Category',"value":"Value",'minor_category':"Specific Crime Category","year":"Year","month":"Month"},inplace = True)
df_can.head(1)
# Out:
#   Police Code   Region Crime Category      Specific Crime Category  Value  \
# 0   E01001116  Croydon       Burglary  Burglary in Other Buildings      0
#
#    Year  Month
# 0  2016     11

# %%
# df_can.dropnul(inplace= True  )

# %%
df_can.dropna(inplace= True  )

# %%
df_can
# Out:
#          Police Code      Region               Crime Category  \
# 0          E01001116     Croydon                     Burglary
# 1          E01001646   Greenwich  Violence Against the Person
# 2          E01000677     Bromley  Violence Against the Person
# 3          E01003774   Redbridge                     Burglary
# 4          E01004563  Wandsworth                      Robbery
# ...              ...         ...                          ...
# 13490599   E01000504       Brent              Criminal Damage
# 13490600   E01002504  Hillingdon                      Robbery
# 13490601   E01004165      Sutton                     Burglary
# 13490602   E01001134     Croydon                      Robbery
# 13490603   E01003413      Merton  Violence Against the Person
#
#               Specific Crime Category  Value  Year  Month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
# %matplotlib inline

import matplotlib as mpl 
import matplotlib.pyplot as plt

# %%
# Region = df_can["Region"]
# Year = df_can["Year"]
# plt.pie(Year,autopct="%1.0f%%",labels=Region,startangle=60)
# plt.axis('Mantab')
# plt.title("Region Vs Year ")
# plt.show()

# %%
# df_can.sort_values(by='Police Code',ascending=False,axis=0, inplace=True)

# %%
df_can
# Out:
#          Police Code      Region               Crime Category  \
# 0          E01001116     Croydon                     Burglary
# 1          E01001646   Greenwich  Violence Against the Person
# 2          E01000677     Bromley  Violence Against the Person
# 3          E01003774   Redbridge                     Burglary
# 4          E01004563  Wandsworth                      Robbery
# ...              ...         ...                          ...
# 13490599   E01000504       Brent              Criminal Damage
# 13490600   E01002504  Hillingdon                      Robbery
# 13490601   E01004165      Sutton                     Burglary
# 13490602   E01001134     Croydon                      Robbery
# 13490603   E01003413      Merton  Violence Against the Person
#
#               Specific Crime Category  Value  Year  Month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
df_can['Value'].isnull().sum()
# Out:
# 0

# %%
data_test = df_can
data_test
# Out:
#          Police Code      Region               Crime Category  \
# 0          E01001116     Croydon                     Burglary
# 1          E01001646   Greenwich  Violence Against the Person
# 2          E01000677     Bromley  Violence Against the Person
# 3          E01003774   Redbridge                     Burglary
# 4          E01004563  Wandsworth                      Robbery
# ...              ...         ...                          ...
# 13490599   E01000504       Brent              Criminal Damage
# 13490600   E01002504  Hillingdon                      Robbery
# 13490601   E01004165      Sutton                     Burglary
# 13490602   E01001134     Croydon                      Robbery
# 13490603   E01003413      Merton  Violence Against the Person
#
#               Specific Crime Category  Value  Year  Month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
print("Matplotlib Version : ", mpl.__version__)
# Out:
# Matplotlib Version :  3.5.1

# %%
print(plt.style.available)
mpl.style.use(['ggplot'])
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
totalregion = data_test['Region'].value_counts()
totalregion
# Out:
# Ealing                    7
# Croydon                   6
# Hackney                   6
# Haringey                  6
# Brent                     5
# Bromley                   5
# Redbridge                 5
# Hounslow                  5
# Newham                    5
# Havering                  4
# Lambeth                   4
# Sutton                    4
# Lewisham                  4
# Barnet                    3
# Westminster               3
# Southwark                 3
# Harrow                    3
# Bexley                    2
# Camden                    2
# Waltham Forest            2
# Islington                 2
# Kingston upon Thames      2
# Greenwich                 2
# Hillingdon                2
# Wandsworth                2
# Enfield                   1
# Barking and Dagenham      1
# Richmond upon Thames      1
# Kensington and Chelsea    1
# Tower Hamlets             1
# Hammersmith and Fulham    1
# Name: Region, dtype: int64

# %%
totalkejatahatantahun = data_test['Year'].value_counts()
totalkejatahatantahun
# Out:
# 2016    16
# 2015    14
# 2008    14
# 2009    13
# 2012    12
# 2013    11
# 2014     7
# 2011     7
# 2010     6
# Name: Year, dtype: int64

# %%
data_test
# Out:
#    Police Code      Region               Crime Category  \
# 0    E01001116     Croydon                     Burglary
# 1    E01001646   Greenwich  Violence Against the Person
# 2    E01000677     Bromley  Violence Against the Person
# 3    E01003774   Redbridge                     Burglary
# 4    E01004563  Wandsworth                      Robbery
# ..         ...         ...                          ...
# 95   E01002093    Haringey  Violence Against the Person
# 96   E01002374    Havering                      Robbery
# 97   E01004142      Sutton                     Burglary
# 98   E01000401      Bexley  Violence Against the Person
# 99   E01000223      Barnet  Violence Against the Person
#
#         Specific Crime Category  Value  Year  Month
# 0   Burglary in Other Buildings      0  2016     11
# 1                Other violence      0  2016     11
# 2                Other violence      0  2015      5
# 3   Burglary in Other Buildings      0  2016      3
# ...

# %%
#Menampilkan total kejahatan besar berdasarkan kategori per tahun dalam bentuk tabel
major = data_test.pivot_table(values='Value', index=['Year'],columns=['Crime Category'], aggfunc=np.sum, fill_value=0)
major
# Out:
# Crime Category  Burglary  Criminal Damage  Drugs  Fraud or Forgery  \
# Year
# 2008                   2                0      0                 0
# 2009                   0                0      0                 0
# 2010                   0                0      0                 0
# 2011                   0                0      0                 0
# 2012                   0                0      0                 0
# 2013                   3                0      0                 0
# 2014                   0                0      0                 0
# 2015                   0                0      0                 0
# 2016                   0                1      0                 0
#
# Crime Category  Other Notifiable Offences  Robbery  Theft and Handling  \
# Year
# 2008                                    0        1                   1
# 2009                                    0        0                   1
# ...

# %%
#Menampilkan total kejahatan kecil berdasarkan kategori per tahun dalam bentuk tabel
minor = df_can.pivot_table(values='Value', index=['Year'],columns=['Specific Crime Category'], aggfunc=np.sum, fill_value=0)
minor
# Out:
# Specific Crime Category  Assault with Injury  Burglary in Other Buildings  \
# Year
# 2008                                   56586                        31437
# 2009                                   55297                        30434
# 2010                                   54173                        29703
# 2011                                   50768                        30876
# 2012                                   50369                        31676
# 2013                                   39929                        30685
# 2014                                   45677                        27078
# 2015                                   48164                        25833
# 2016                                   50038                        25289
#
# Specific Crime Category  Burglary in a Dwelling  Business Property  \
# Year
# 2008                                      56655               2964
# 2009                                      60185               3115
# ...

# %% [markdown]
# # Area Plot
# Kategori kejahatan besar di London tahun 2008 - 2016

# %%
major.plot(kind='area',
           alpha=0.35,
           stacked=False,
           figsize=(20, 10),
          )

plt.title('Area Plot Kejahatan Besar di London Tahun 2008 - 2016')
plt.ylabel('Total Kejahatan') 
plt.xlabel('Tahun') 

plt.show()

# %% [markdown]
# # Histograms
# Kejahatan besar di London yang paling banyak dan paling sedikit dari tahun 2008 - 2016 dalam bentuk histogram!

# %%
count, bin_edges = np.histogram(major, 15)
major.plot(kind ='hist',
figsize=(20, 10),
bins=15,
alpha=0.6,
xticks=bin_edges,
)

plt.title('Kejahatan Besar di London Tahun 2008 - 2016') 
plt.ylabel('Total Tahun') 
plt.xlabel('Total Kejahatan')

plt.show()

# %% [markdown]
# Kejahatan besar paling banyak di London tahun 2008 - 2016 adalah "Other Notifable Offences ". Sedangkan kejahatan besar paling sedikit adalah "Sexual Offences".

# %% [markdown]
# # Bar Charts
# Soal: Kasus kejahatan di City of London pada tahun 2016

# %%
databar = data_test[["Police Code","Region","Crime Category","Value","Year","Month"]][data_test.Year == 2016]

# Cek Data
databar
# Out:
#          Police Code                  Region               Crime Category  \
# 0          E01001116                 Croydon                     Burglary
# 1          E01001646               Greenwich  Violence Against the Person
# 3          E01003774               Redbridge                     Burglary
# 9          E01004177                  Sutton           Theft and Handling
# 14         E01002398              Hillingdon           Theft and Handling
# ...              ...                     ...                          ...
# 13490538   E01003920               Southwark  Violence Against the Person
# 13490565   E01004742             Westminster           Theft and Handling
# 13490574   E01002823  Kensington and Chelsea           Theft and Handling
# 13490579   E01004100                  Sutton                        Drugs
# 13490591   E01000193                  Barnet              Criminal Damage
#
#           Value  Year  Month
# 0             0  2016     11
# ...

# %%
region =  databar.pivot_table(values='Value', index=['Month'],columns=['Region'], aggfunc=np.sum, fill_value=0)
region
# Out:
# Region  Barking and Dagenham  Barnet  Bexley  Brent  Bromley  Camden  \
# Month
# 1                       1376    1982    1120   2124     1692    2335
# 2                       1371    1925    1019   2057     1647    2363
# 3                       1491    2106    1065   2126     1695    2290
# 4                       1339    2106     915   2116     1530    2254
# 5                       1555    2159     998   2406     1708    2501
# 6                       1449    2110    1048   2316     1607    2365
# 7                       1534    2062    1093   2285     1780    2585
# 8                       1346    2043     994   2269     1537    2476
# 9                       1363    2110    1106   2185     1595    2425
# 10                      1323    2074    1148   2366     1758    2542
# 11                      1316    2032    1152   2158     1755    2419
# 12                      1278    1975    1182   2285     1860    2628
#
# ...

# %%
region =  databar.pivot_table(values='Value', index=['Month'],columns=['Region'], aggfunc=np.sum, fill_value=0)
dfregion = region['City of London']
dfregion.plot(kind='bar', figsize=(10,6), color='khaki')

plt.xlabel('Bulan')
plt.ylabel('Total Kejahatan')
plt.title('Kasus Kejahatan di City of London Tahun 2016')

plt.show()

# %%
totalborough = databar['Region'].value_counts()
barh=totalborough[0:10]

barh.plot(kind='barh', figsize=(20,10), color='rosybrown')

plt.xlabel('Total Kejahatan')
plt.ylabel('Wilayah')
plt.title('Kasus Kejahatan di London berdasarkan Wilayah Tahun 2008 - 2016')

plt.show()

# %%
minor1 = df_can['Specific Crime Category'].value_counts()
minor2=minor1[0:10]

minor2.plot(kind='barh', figsize=(20,10), color='darkslateblue')

plt.xlabel('Total Kejahatan')
plt.ylabel('Kategori Kejahatan Kecil')
plt.title('Kasus Kejahatan Kecil di London Tahun 2008 - 2016')

plt.show()

# %% [markdown]
# # Pie Charts

# %%
totalcrimes = df_can['Year'].value_counts()
years = pd.DataFrame(data=totalcrimes.index, columns=["Year"])
years['Values'] = totalcrimes.values

# %%
fig = px.pie(years, values='Values', names='Year', color_discrete_sequence=px.colors.qualitative.Pastel1)
fig.show()
# Out:
# <div>                            <div id="ee6b51b2-94be-4722-a74a-c1138f95c76b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee6b51b2-94be-4722-a74a-c1138f95c76b")) {                    Plotly.newPlot(                        "ee6b51b2-94be-4722-a74a-c1138f95c76b",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Year=%{label}<br>Values=%{value}<extra></extra>","labels":[2016,2015,2008,2012,2010,2013,2014,2011,2009],"legendgroup":"","name":"","showlegend":true,"values":[1498956,1498956,1498956,1498956,1498956,1498956,1498956,1498956,1498956],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},
# ...

# %%
colors_list = ['darkslateblue','lightsteelblue','orange','moccasin','forestgreen','darkseagreen','darkorchid','plum','rosybrown']
explode_list = [0.1, 0, 0, 0, 0, 0, 0, 0.2, 0.4]
dfpie = df_can.groupby(['Crime Category']).sum()['Value'].sort_values(ascending=False)
dfpie.plot(kind='pie',
           figsize=(15, 6),
           autopct='%1.1f%%',
           startangle=90,
           shadow=True,
           labels=None, 
           colors=colors_list,
           pctdistance=1.12,
           explode=explode_list
          )
plt.title('Persentase Kejahatan Besar di London Tahun 2008 - 2016', y=1.12)
plt.ylabel('')
plt.axis('equal')

plt.legend(labels=dfpie.index, loc='upper right')

plt.show()

# %% [markdown]
# # Box Plot

# %%
harassment = minor['Harassment']
harassment.plot(kind='box', figsize=(10, 8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Scatter Plots

# %%
dfscatter = major[['Theft and Handling','Criminal Damage']]
dfscatter = dfscatter.reset_index()
dfscatter
# Out:
# Crime Category  Year  Theft and Handling  Criminal Damage
# 0               2008                   1                0
# 1               2009                   1                0
# 2               2010                   0                0
# 3               2011                   0                0
# 4               2012                   3                0
# 5               2013                   0                0
# 6               2014                   1                0
# 7               2015                   0                0
# 8               2016                   5                1

# %%
ax1 = dfscatter.plot(kind='scatter', x='Year', y='Theft and Handling', figsize=(10, 6), color='seagreen', label='Theft and Handling')
ax2 = dfscatter.plot(kind='scatter', x='Year', y='Criminal Damage', figsize=(10, 6), color='orange',label='Criminal Damage', ax=ax1 )

plt.title('Perbandingan antara Theft and Handling dan Criminal Damage di London Tahun 2008 - 2016')
plt.xlabel('Tahun')
plt.ylabel('Total Kasus')

plt.show()

# %% [markdown]
# # Word Clouds

# %%
from wordcloud import WordCloud, STOPWORDS
stopwords=set(STOPWORDS)

# %%
dataregion = ' '.join(df_can.Region)

# %%
region_wc = WordCloud(
background_color='white',
max_words=100,
stopwords=stopwords
)

# generate the word cloud
region_wc.generate(dataregion)

# %%
plt.imshow(region_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
uper = np.array(Image.open('Anjay.png'))

# %%
fig=plt.figure()
fig.set_figwidth(14)
fig.set_figheight(18)

plt.imshow(uper,cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
minor_wc = WordCloud(background_color='white', max_words=300,
                    mask=uper, stopwords=stopwords)

minor_wc.generate(dataregion)

fig=plt.figure()
fig.set_figwidth(14)
fig.set_figheight(18)

plt.imshow(minor_wc,interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# # Folium Maps

# %%
latitude = 51.50
longitude = -0.136

# %%
london_map = folium.Map(location=[latitude,longitude], zoom_start=12)
london_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...
